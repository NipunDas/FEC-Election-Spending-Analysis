# %%
import polars as pl
import constants

# %%
df = pl.read_parquet(constants.CONTRIBUTIONS_TABLE_PARQUET_PATH)

# %%
df
# Out:
# shape: (117_359, 17)
# ┌────────────┬────────────┬───────────┬────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ transactio ┆ transactio ┆ date      ┆ amount ┆ … ┆ candidate ┆ recipient ┆ election. ┆ ico.statu │
# │ n.id       ┆ n.type     ┆ ---       ┆ ---    ┆   ┆ .party    ┆ .state    ┆ type      ┆ s         │
# │ ---        ┆ ---        ┆ date      ┆ i64    ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │ str        ┆ str        ┆           ┆        ┆   ┆ str       ┆ str       ┆ str       ┆ str       │
# ╞════════════╪════════════╪═══════════╪════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ comm:1980: ┆ 24K        ┆ 1979-06-1 ┆ 250    ┆ … ┆ Democrat  ┆ HI        ┆ P         ┆ I         │
# │ 100003     ┆            ┆ 9         ┆        ┆   ┆           ┆           ┆           ┆           │
# │ comm:1980: ┆ 24K        ┆ 1979-08-1 ┆ 25     ┆ … ┆ Republica ┆ IL        ┆ P         ┆ I         │
# ...

# %%
df.null_count()
# Out:
# shape: (1, 17)
# ┌─────────────┬────────────┬──────┬────────┬───┬────────────┬────────────┬────────────┬────────────┐
# │ transaction ┆ transactio ┆ date ┆ amount ┆ … ┆ candidate. ┆ recipient. ┆ election.t ┆ ico.status │
# │ .id         ┆ n.type     ┆ ---  ┆ ---    ┆   ┆ party      ┆ state      ┆ ype        ┆ ---        │
# │ ---         ┆ ---        ┆ u32  ┆ u32    ┆   ┆ ---        ┆ ---        ┆ ---        ┆ u32        │
# │ u32         ┆ u32        ┆      ┆        ┆   ┆ u32        ┆ u32        ┆ u32        ┆            │
# ╞═════════════╪════════════╪══════╪════════╪═══╪════════════╪════════════╪════════════╪════════════╡
# │ 0           ┆ 0          ┆ 0    ┆ 0      ┆ … ┆ 0          ┆ 0          ┆ 6          ┆ 752        │
# └─────────────┴────────────┴──────┴────────┴───┴────────────┴────────────┴────────────┴────────────┘

# %%
df['ico.status'].unique()
# Out:
# shape: (5,)
# Series: 'ico.status' [str]
# [
# 	"I"
# 	""
# 	null
# 	"O"
# 	"C"
# ]
